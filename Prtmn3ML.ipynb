# %% [markdown]
# <a href="https://colab.research.google.com/github/nur545315-oss/MachineLearning/blob/main/Prtmn3ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd, seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('iris')
df.info()             # struktur & tipe data
df.isnull().sum()     # cek nilai hilang

sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show(             # matriks korelasi
